# %%
import cv2
import os

# Set the base directory where you want to save the images
base_dir = r'E:\project\RealTimeFaceMaskDetection'

# Create directories for masked and unmasked images under the base directory
masked_dir = os.path.join(base_dir, 'masked')
unmasked_dir = os.path.join(base_dir, 'unmasked')

# Print out the paths
print("Path for Masked Images:", masked_dir)
print("Path for Unmasked Images:", unmasked_dir)

os.makedirs(masked_dir, exist_ok=True)
os.makedirs(unmasked_dir, exist_ok=True)

# Initialize webcam
cap = cv2.VideoCapture(0)

# Set image dimensions
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Display the frame
    cv2.imshow('Capture Images (Press "m" for Masked, "u" for Unmasked)', frame)
    
    # Capture key press
    key = cv2.waitKey(1)
    
    # Save image if "m" is pressed for Masked or "u" is pressed for Unmasked
    if key == ord('m'):
        img_name = f'{masked_dir}/masked_{len(os.listdir(masked_dir)) + 1}.jpg'
        cv2.imwrite(img_name, frame)
        print(f'Saved: {img_name}')
    elif key == ord('u'):
        img_name = f'{unmasked_dir}/unmasked_{len(os.listdir(unmasked_dir)) + 1}.jpg'
        cv2.imwrite(img_name, frame)
        print(f'Saved: {img_name}')
    
    # Break loop if 'q' is pressed
    elif key == ord('q'):
        break

# Release video capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Path for Masked Images: E:\project\RealTimeFaceMaskDetection\masked
# Path for Unmasked Images: E:\project\RealTimeFaceMaskDetection\unmasked

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !pip install Pillow
# Out:
# Collecting Pillow
#   Downloading pillow-10.2.0-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Downloading pillow-10.2.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.6 MB 5.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.6 MB 4.8 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.6 MB 4.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 4.6 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.6 MB 4.1 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 3.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.2/2.6 MB 3.3 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 3.0 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.6 MB 2.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.6 MB 2.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 2.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.6 MB 2.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 2.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.4/2.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.6 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.6 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 999.2 kB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.6 MB 993.8 kB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 988.2 kB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 978.1 kB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 954.0 kB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 929.2 kB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.6 MB 920.3 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 910.2 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 894.7 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 881.2 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 881.2 kB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 859.9 kB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 859.9 kB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 852.0 kB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.6 MB 844.6 kB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 830.9 kB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 825.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.6 MB 816.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.6 MB 816.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 806.4 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 796.0 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.6 MB 786.6 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 785.3 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 779.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 763.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 763.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 750.4 kB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 745.4 kB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 744.6 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 739.7 kB/s eta 0:00:01
#    ------------------------------------- -- 2.5/2.6 MB 744.6 kB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 740.3 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 745.3 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 744.3 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 740.7 kB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 736.4 kB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 726.9 kB/s eta 0:00:00
# Installing collected packages: Pillow
# Successfully installed Pillow-10.2.0

# %%
# !pip uninstall Pillow
# !pip install Pillow

# %%
# Set directories for masked and unmasked images
train_dir = 'E:/project/RealTimeFaceMaskDetection/'

# Set image dimensions
img_width, img_height = 224, 224

# Data Generator
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Train Generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

# Validation Generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Model Architecture
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile Model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train Model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator)

# Save Model
model.save('face_mask_detection_model.h5')
# Out:
# Found 88 images belonging to 2 classes.
# Found 22 images belonging to 2 classes.
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/10
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.4076 - loss: 0.7257 - val_accuracy: 0.5000 - val_loss: 0.6873
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step - accuracy: 0.6413 - loss: 0.6733 - val_accuracy: 0.8636 - val_loss: 0.6319
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 0.8604 - loss: 0.5831 - val_accuracy: 0.7727 - val_loss: 0.5507
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 585ms/step - accuracy: 0.9098 - loss: 0.4605 - val_accuracy: 0.8182 - val_loss: 0.5240
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 609ms/step - accuracy: 0.8816 - loss: 0.3617 - val_accuracy: 0.7727 - val_loss: 0.3772
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 472ms/step - accuracy: 0.9324 - loss: 0.2304 - val_accuracy: 0.7727 - val_loss: 0.3338
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 532ms/step - accuracy: 0.9634 - loss: 0.1589 - val_accuracy: 0.8636 - val_loss: 0.2951
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 0.9740 - loss: 0.1157 - val_accuracy: 0.8636 - val_loss: 0.2779
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 528ms/step - accuracy: 0.9943 - loss: 0.0699 - val_accuracy: 0.8636 - val_loss: 0.3740
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 578ms/step - accuracy: 0.9943 - loss: 0.0440 - val_accuracy: 0.8636 - val_loss: 0.2444
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set directories for masked and unmasked images
train_dir = 'E:/project/RealTimeFaceMaskDetection/'

# Set image dimensions
img_width, img_height = 224, 224

# Data Generator
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Train Generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

# Validation Generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Model Architecture
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile Model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train Model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator)

# Save Model in native Keras format
model.save('face_mask_detection_model.keras')
# Out:
# Found 88 images belonging to 2 classes.
# Found 22 images belonging to 2 classes.
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/10
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5622 - loss: 2.1381 - val_accuracy: 0.5000 - val_loss: 0.7039
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 574ms/step - accuracy: 0.4688 - loss: 0.7205 - val_accuracy: 0.5000 - val_loss: 0.6829
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 593ms/step - accuracy: 0.5281 - loss: 0.6850 - val_accuracy: 0.5000 - val_loss: 0.6748
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 559ms/step - accuracy: 0.7065 - loss: 0.6675 - val_accuracy: 0.8636 - val_loss: 0.6588
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step - accuracy: 0.8221 - loss: 0.6406 - val_accuracy: 0.6364 - val_loss: 0.6328
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - accuracy: 0.7805 - loss: 0.6111 - val_accuracy: 0.7727 - val_loss: 0.6073
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 562ms/step - accuracy: 0.8197 - loss: 0.5396 - val_accuracy: 0.8636 - val_loss: 0.5560
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9097 - loss: 0.4629 - val_accuracy: 0.8182 - val_loss: 0.4823
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 580ms/step - accuracy: 0.9145 - loss: 0.3591 - val_accuracy: 0.7727 - val_loss: 0.4981
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 622ms/step - accuracy: 0.8804 - loss: 0.3246 - val_accuracy: 0.7727 - val_loss: 0.3784

# %%
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('face_mask_detection_model.keras')

# Define the validation directory
validation_dir = 'E:/project/RealTimeFaceMaskDetection/'

# Set image dimensions
img_width, img_height = 224, 224

# Load and preprocess validation data
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary'
)

# Evaluate the model on the validation dataset
loss, accuracy = model.evaluate(validation_generator)

# Print the accuracy
print("Validation Accuracy:", accuracy)
# Out:
# Found 110 images belonging to 2 classes.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 0.8710 - loss: 0.2654
# Validation Accuracy: 0.8545454740524292

# %%
#using the trained model to implement the real time prediction model
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
# Load the trained model
model = load_model('face_mask_detection_model.keras')

# Initialize the face cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Initialize the video capture object
cap = cv2.VideoCapture(0)

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Load the trained model
model = load_model('face_mask_detection_model.keras')

# Initialize the face cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Initialize the video capture object
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the video stream
    ret, frame = cap.read()
    if not ret:
        break

    # Convert the frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_img = frame[y:y+h, x:x+w]
        
        # Preprocess the face ROI for model input
        face_input = cv2.resize(face_img, (224, 224))
        face_input = img_to_array(face_input)
        face_input = preprocess_input(face_input)
        face_input = np.expand_dims(face_input, axis=0)

        # Perform mask detection inference
        prediction = model.predict(face_input)[0]
        
        # Determine the label based on prediction probability
        label = "Mask" if prediction < 0.5 else "No Mask"
        
        # Display the label and bounding box around the face
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)

    # Display the annotated frame
    cv2.imshow('Face Mask Detection', frame)

    # Exit if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release video capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.4 kB 108.9 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 238.1 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 229.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\tonmo\anaconda3\envs\myenv\lib\site-packages (from scipy) (1.26.4)
# Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl (45.8 MB)
#    ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.8 MB 2.3 MB/s eta 0:00:20
#    ---------------------------------------- 0.5/45.8 MB 5.8 MB/s eta 0:00:08
#     --------------------------------------- 0.9/45.8 MB 7.2 MB/s eta 0:00:07
#    - -------------------------------------- 1.4/45.8 MB 8.2 MB/s eta 0:00:06
#    - -------------------------------------- 1.9/45.8 MB 8.5 MB/s eta 0:00:06
#    - -------------------------------------- 2.3/45.8 MB 8.5 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/45.8 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.9/45.8 MB 4.9 MB/s eta 0:00:09
#    -- ------------------------------------- 3.4/45.8 MB 5.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/45.8 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 4.2/45.8 MB 5.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.6/45.8 MB 5.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.1/45.8 MB 6.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 6.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/45.8 MB 2.1 MB/s eta 0:00:20
#    ---- ----------------------------------- 5.4/45.8 MB 2.1 MB/s eta 0:00:20
#    ----- ---------------------------------- 5.7/45.8 MB 2.2 MB/s eta 0:00:19
#    ----- ---------------------------------- 6.2/45.8 MB 2.3 MB/s eta 0:00:18
#    ----- ---------------------------------- 6.6/45.8 MB 2.4 MB/s eta 0:00:17
#    ------ --------------------------------- 6.9/45.8 MB 2.5 MB/s eta 0:00:16
#    ------ --------------------------------- 7.4/45.8 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.8/45.8 MB 2.7 MB/s eta 0:00:14
#    ------- -------------------------------- 8.3/45.8 MB 2.9 MB/s eta 0:00:14
#    ------- -------------------------------- 8.8/45.8 MB 3.0 MB/s eta 0:00:13
#    -------- ------------------------------- 9.3/45.8 MB 3.1 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.6/45.8 MB 3.2 MB/s eta 0:00:12
#    -------- ------------------------------- 9.7/45.8 MB 2.1 MB/s eta 0:00:18
#    -------- ------------------------------- 10.1/45.8 MB 2.1 MB/s eta 0:00:17
#    --------- ------------------------------ 10.5/45.8 MB 2.2 MB/s eta 0:00:17
#    --------- ------------------------------ 10.9/45.8 MB 2.2 MB/s eta 0:00:17
#    --------- ------------------------------ 11.3/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 11.6/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.1/45.8 MB 2.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 12.2/45.8 MB 2.0 MB/s eta 0:00:17
#    ---------- ----------------------------- 12.5/45.8 MB 2.0 MB/s eta 0:00:17
#    ----------- ---------------------------- 12.8/45.8 MB 2.0 MB/s eta 0:00:17
#    ----------- ---------------------------- 13.2/45.8 MB 2.1 MB/s eta 0:00:16
#    ----------- ---------------------------- 13.5/45.8 MB 2.1 MB/s eta 0:00:16
#    ------------ --------------------------- 14.0/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.4/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.7/45.8 MB 2.1 MB/s eta 0:00:15
#    ------------ --------------------------- 14.9/45.8 MB 1.9 MB/s eta 0:00:17
#    ------------- -------------------------- 15.3/45.8 MB 1.8 MB/s eta 0:00:17
#    ------------- -------------------------- 15.7/45.8 MB 2.7 MB/s eta 0:00:12
#    -------------- ------------------------- 16.3/45.8 MB 2.7 MB/s eta 0:00:12
#    -------------- ------------------------- 16.7/45.8 MB 2.7 MB/s eta 0:00:11
#    -------------- ------------------------- 17.1/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/45.8 MB 2.7 MB/s eta 0:00:11
#    --------------- ------------------------ 17.5/45.8 MB 2.2 MB/s eta 0:00:13
#    --------------- ------------------------ 17.8/45.8 MB 2.2 MB/s eta 0:00:13
#    --------------- ------------------------ 18.1/45.8 MB 2.2 MB/s eta 0:00:13
#    ---------------- ----------------------- 18.5/45.8 MB 2.2 MB/s eta 0:00:13
#    ---------------- ----------------------- 19.0/45.8 MB 2.2 MB/s eta 0:00:13
#    ---------------- ----------------------- 19.4/45.8 MB 2.2 MB/s eta 0:00:13
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.7/45.8 MB 2.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 19.8/45.8 MB 1.9 MB/s eta 0:00:14
#    ----------------- ---------------------- 20.1/45.8 MB 2.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 20.3/45.8 MB 2.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 20.6/45.8 MB 2.7 MB/s eta 0:00:10
#    ------------------ --------------------- 20.9/45.8 MB 2.7 MB/s eta 0:00:10
#    ------------------ --------------------- 21.1/45.8 MB 2.7 MB/s eta 0:00:10
#    ------------------ --------------------- 21.5/45.8 MB 2.7 MB/s eta 0:00:10
#    ------------------- -------------------- 21.8/45.8 MB 2.7 MB/s eta 0:00:10
#    ------------------- -------------------- 22.2/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.3/45.8 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.5/45.8 MB 2.4 MB/s eta 0:00:10
#    ------------------- -------------------- 22.7/45.8 MB 2.4 MB/s eta 0:00:10
#    ------------------- -------------------- 22.9/45.8 MB 2.4 MB/s eta 0:00:10
#    -------------------- ------------------- 23.2/45.8 MB 2.4 MB/s eta 0:00:10
#    -------------------- ------------------- 23.4/45.8 MB 2.4 MB/s eta 0:00:10
#    -------------------- ------------------- 23.6/45.8 MB 2.3 MB/s eta 0:00:10
#    -------------------- ------------------- 23.9/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.2/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.4/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.7/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.8/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 24.9/45.8 MB 2.0 MB/s eta 0:00:11
#    --------------------- ------------------ 24.9/45.8 MB 2.3 MB/s eta 0:00:10
#    --------------------- ------------------ 25.1/45.8 MB 2.3 MB/s eta 0:00:10
#    ---------------------- ----------------- 25.3/45.8 MB 2.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 25.5/45.8 MB 2.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 25.7/45.8 MB 2.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 25.9/45.8 MB 2.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 26.1/45.8 MB 2.2 MB/s eta 0:00:09
#    ---------------------- ----------------- 26.3/45.8 MB 2.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 26.5/45.8 MB 2.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 26.7/45.8 MB 2.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 26.9/45.8 MB 2.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.2/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 27.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 27.5/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 27.6/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 27.7/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 27.9/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 28.1/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 28.3/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 28.4/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------ --------------- 28.6/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------- -------------- 28.8/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------- -------------- 28.9/45.8 MB 2.1 MB/s eta 0:00:09
#    ------------------------- -------------- 29.2/45.8 MB 2.0 MB/s eta 0:00:09
#    ------------------------- -------------- 29.4/45.8 MB 2.0 MB/s eta 0:00:09
#    ------------------------- -------------- 29.6/45.8 MB 2.0 MB/s eta 0:00:09
#    -------------------------- ------------- 29.9/45.8 MB 2.0 MB/s eta 0:00:08
#    -------------------------- ------------- 29.9/45.8 MB 2.0 MB/s eta 0:00:08
#    -------------------------- ------------- 30.0/45.8 MB 2.0 MB/s eta 0:00:09
#    -------------------------- ------------- 30.2/45.8 MB 2.3 MB/s eta 0:00:07
#    -------------------------- ------------- 30.4/45.8 MB 2.3 MB/s eta 0:00:07
#    -------------------------- ------------- 30.6/45.8 MB 2.3 MB/s eta 0:00:07
#    -------------------------- ------------- 30.8/45.8 MB 2.3 MB/s eta 0:00:07
#    --------------------------- ------------ 31.0/45.8 MB 2.3 MB/s eta 0:00:07
#    --------------------------- ------------ 31.2/45.8 MB 2.3 MB/s eta 0:00:07
#    --------------------------- ------------ 31.4/45.8 MB 2.3 MB/s eta 0:00:07
#    --------------------------- ------------ 31.7/45.8 MB 2.3 MB/s eta 0:00:07
#    --------------------------- ------------ 31.9/45.8 MB 2.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 32.1/45.8 MB 2.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 32.3/45.8 MB 2.2 MB/s eta 0:00:07
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.4/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.5/45.8 MB 1.9 MB/s eta 0:00:07
#    ---------------------------- ----------- 32.7/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.8/45.8 MB 2.2 MB/s eta 0:00:06
#    ---------------------------- ----------- 33.1/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 33.3/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 33.5/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 33.7/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 33.9/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 34.1/45.8 MB 2.2 MB/s eta 0:00:06
#    ----------------------------- ---------- 34.3/45.8 MB 2.2 MB/s eta 0:00:06
#    ------------------------------ --------- 34.6/45.8 MB 2.2 MB/s eta 0:00:06
#    ------------------------------ --------- 34.8/45.8 MB 2.2 MB/s eta 0:00:06
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.0/45.8 MB 1.9 MB/s eta 0:00:06
#    ------------------------------ --------- 35.1/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.3/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 35.4/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------- -------- 35.8/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------- -------- 36.0/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------- -------- 36.3/45.8 MB 2.2 MB/s eta 0:00:05
#    ------------------------------- -------- 36.6/45.8 MB 2.2 MB/s eta 0:00:05
#    -------------------------------- ------- 36.9/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.1/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.4/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 37.5/45.8 MB 1.9 MB/s eta 0:00:05
#    -------------------------------- ------- 37.7/45.8 MB 2.2 MB/s eta 0:00:04
#    --------------------------------- ------ 37.8/45.8 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 38.0/45.8 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 38.3/45.8 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 38.5/45.8 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 38.7/45.8 MB 2.3 MB/s eta 0:00:04
#    --------------------------------- ------ 38.9/45.8 MB 2.3 MB/s eta 0:00:04
#    ---------------------------------- ----- 39.2/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 39.4/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 39.7/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 39.9/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.0/45.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.1/45.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 40.2/45.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 40.4/45.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 40.6/45.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 40.8/45.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 41.0/45.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------------------ --- 41.2/45.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------------------ --- 41.5/45.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------------------ --- 41.7/45.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------------------ --- 41.9/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 42.1/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 42.4/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 42.6/45.8 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------- -- 42.8/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 43.0/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 43.2/45.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 43.4/45.8 MB 2.0 MB/s eta 0:00:02
#    -------------------------------------- - 43.6/45.8 MB 2.0 MB/s eta 0:00:02
#    -------------------------------------- - 43.8/45.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/45.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 44.2/45.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 44.4/45.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 44.7/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  44.9/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.6/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 45.8/45.8 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.12.0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# Set directories for masked and unmasked images
train_dir = 'E:/project/RealTimeFaceMaskDetection/'

# Set image dimensions
img_width, img_height = 224, 224

# Set batch size and number of epochs
batch_size = 32
epochs = 20

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

# Load and preprocess training data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

# Load and preprocess validation data
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

# Load MobileNetV2 base model
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_tensor=Input(shape=(img_width, img_height, 3))
)

# Construct the head of the model
head_model = base_model.output
head_model = AveragePooling2D(pool_size=(7, 7))(head_model)
head_model = Flatten(name='flatten')(head_model)
head_model = Dense(128, activation='relu')(head_model)
head_model = Dropout(0.5)(head_model)
head_model = Dense(1, activation='sigmoid')(head_model)

# Combine the base and head models
model = Model(inputs=base_model.input, outputs=head_model)

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
opt = Adam(learning_rate=1e-4)  # Specify learning_rate instead of lr
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True),
    ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1)
]

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs,
    callbacks=callbacks
)

# Evaluate the model
loss, accuracy = model.evaluate(validation_generator)
print("Validation Loss:", loss)
print("Validation Accuracy:", accuracy)

# Save the entire model
model.save('face_mask_detection_model.keras')
# Out:
# Found 88 images belonging to 2 classes.
# Found 22 images belonging to 2 classes.
# C:\Users\tonmo\AppData\Local\Temp\ipykernel_9028\3638335838.py:52: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Epoch 1/20
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.6585 - loss: 0.7702
# Epoch 1: val_accuracy improved from -inf to 0.72727, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 28s 8s/step - accuracy: 0.6592 - loss: 0.7573 - val_accuracy: 0.7273 - val_loss: 0.5869
# Epoch 2/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4375 - loss: 0.8517
# C:\Users\tonmo\anaconda3\envs\myenv\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# Epoch 2: val_accuracy did not improve from 0.72727
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4375 - loss: 0.6388 - val_accuracy: 0.6818 - val_loss: 0.6161
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 700ms/step - accuracy: 0.5670 - loss: 0.6773
# Epoch 3: val_accuracy improved from 0.72727 to 0.86364, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.5685 - loss: 0.6837 - val_accuracy: 0.8636 - val_loss: 0.5635
# Epoch 4/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.5938 - loss: 0.7090
# Epoch 4: val_accuracy did not improve from 0.86364
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.5938 - loss: 0.5317 - val_accuracy: 0.7727 - val_loss: 0.5070
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - accuracy: 0.6641 - loss: 0.6040
# Epoch 5: val_accuracy did not improve from 0.86364
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.6562 - loss: 0.6122 - val_accuracy: 0.7727 - val_loss: 0.5127
# Epoch 6/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.4583 - loss: 0.7906
# Epoch 6: val_accuracy did not improve from 0.86364
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.4583 - loss: 0.5930 - val_accuracy: 0.6818 - val_loss: 0.5564
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 885ms/step - accuracy: 0.6071 - loss: 0.7265
# Epoch 7: val_accuracy did not improve from 0.86364
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6012 - loss: 0.7305 - val_accuracy: 0.7727 - val_loss: 0.4595
# Epoch 8/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.8125 - loss: 0.4974
# Epoch 8: val_accuracy did not improve from 0.86364
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.8125 - loss: 0.3730 - val_accuracy: 0.8636 - val_loss: 0.4485
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.6652 - loss: 0.5662
# Epoch 9: val_accuracy improved from 0.86364 to 0.90909, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.6577 - loss: 0.5787 - val_accuracy: 0.9091 - val_loss: 0.4631
# Epoch 10/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.7188 - loss: 0.5318
# Epoch 10: val_accuracy did not improve from 0.90909
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7188 - loss: 0.3988 - val_accuracy: 0.8636 - val_loss: 0.4473
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.7812 - loss: 0.5455
# Epoch 11: val_accuracy improved from 0.90909 to 0.95455, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.7812 - loss: 0.5416 - val_accuracy: 0.9545 - val_loss: 0.3753
# Epoch 12/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.7917 - loss: 0.5419
# Epoch 12: val_accuracy did not improve from 0.95455
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7917 - loss: 0.4064 - val_accuracy: 0.8636 - val_loss: 0.3725
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - accuracy: 0.7173 - loss: 0.5300
# Epoch 13: val_accuracy did not improve from 0.95455
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7341 - loss: 0.5213 - val_accuracy: 0.9545 - val_loss: 0.3084
# Epoch 14/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 934ms/step - accuracy: 0.7500 - loss: 0.5466
# Epoch 14: val_accuracy did not improve from 0.95455
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7500 - loss: 0.4100 - val_accuracy: 0.9545 - val_loss: 0.3089
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.7924 - loss: 0.4471
# Epoch 15: val_accuracy did not improve from 0.95455
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7961 - loss: 0.4413 - val_accuracy: 0.8636 - val_loss: 0.3480
# Epoch 16/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 891ms/step - accuracy: 0.7500 - loss: 0.5206
# Epoch 16: val_accuracy improved from 0.95455 to 1.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.7500 - loss: 0.3905 - val_accuracy: 1.0000 - val_loss: 0.2955
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 892ms/step - accuracy: 0.7024 - loss: 0.4742
# Epoch 17: val_accuracy did not improve from 1.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7004 - loss: 0.4846 - val_accuracy: 1.0000 - val_loss: 0.3116
# Epoch 18/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.8750 - loss: 0.3721
# Epoch 18: val_accuracy did not improve from 1.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.8750 - loss: 0.2791 - val_accuracy: 1.0000 - val_loss: 0.2686
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 893ms/step - accuracy: 0.6488 - loss: 0.5392
# Epoch 19: val_accuracy did not improve from 1.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6706 - loss: 0.5211 - val_accuracy: 1.0000 - val_loss: 0.2955
# Epoch 20/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.8438 - loss: 0.4160
# Epoch 20: val_accuracy did not improve from 1.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.8438 - loss: 0.3120 - val_accuracy: 0.9091 - val_loss: 0.2795
# Restoring model weights from the end of the best epoch: 18.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9545 - loss: 0.2907
# Validation Loss: 0.29071566462516785
# Validation Accuracy: 0.9545454382896423

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

# Load the saved model
model = load_model('face_mask_detection_model.keras')  # Load the saved .keras model file

# Load the face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start the video capture
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the video stream
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert the frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Process each detected face
    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = frame[y:y+h, x:x+w]

        # Preprocess the face ROI for model input
        face_input = cv2.resize(face_roi, (224, 224))
        face_input = img_to_array(face_input)
        face_input = preprocess_input(face_input)
        face_input = np.expand_dims(face_input, axis=0)

        # Predict if the face is wearing a mask or not
        prediction = model.predict(face_input)[0]

        # Determine the label and color for the bounding box and text
        label = "Mask" if prediction < 0.5 else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

        # Display the label and bounding box around the face
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)

    # Display the annotated frame
    cv2.imshow('Face Mask Detection', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
